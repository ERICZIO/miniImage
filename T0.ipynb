# %% [markdown]
# 原始数据：
#
# 1.   github: https://github.com/Runist/torch_maml
# 2.   csdn: https://blog.csdn.net/weixin_42392454/article/details/109891791
# 3.   paper: https://arxiv.org/abs/1810.09502
#
# 使用说明：
# 1.上传image数据集以及train,test,val.csv
#
# 2.注释掉model.models.__init__.py中的代码
#
# 3.上传Res12-pre.pth,在ulils.py中修改文件路径为绝对路径
#
# 4.将原始data文件移动到content
#
# 5.创建路径 ./UNICORN-MAML/data/miniimagenet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! git clone https://github.com/Han-Jia/UNICORN-MAML
# Out:
# Cloning into 'UNICORN-MAML'...
# remote: Enumerating objects: 100, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 100 (delta 15), reused 12 (delta 12), pack-reused 79
# Receiving objects: 100% (100/100), 4.06 MiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
! pip install jpeg4py
! pip install 'git+https://github.com/lanpa/tensorboardX'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jpeg4py: filename=jpeg4py-0.1.4-py3-none-any.whl size=8424 sha256=044a1b3766ae8e9015da359350c705cc102bec7887d423ee49d0702de4b6ecef
#   Stored in directory: /root/.cache/pip/wheels/86/c3/0f/348e6cadb3a27435e833d21d91707d653fb159d69f2a867a36
# Successfully built jpeg4py
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/lanpa/tensorboardX to /tmp/pip-req-build-sc2c75aw
#   Running command git clone --filter=blob:none --quiet https://github.com/lanpa/tensorboardX /tmp/pip-req-build-sc2c75aw
#   Resolved https://github.com/lanpa/tensorboardX to commit 65b74d1fff77422dabff456226c3a0327187d175
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 20.0 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir('/content/data/miniimagenet')
! unzip /content/drive/MyDrive/Eric/MAML++/images.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: image/n0679411000000879.jpg
#   inflating: image/n0679411000000880.jpg
#   inflating: image/n0679411000000881.jpg
#   inflating: image/n0679411000000882.jpg
#   inflating: image/n0679411000000885.jpg
#   inflating: image/n0679411000000894.jpg
#   inflating: image/n0679411000000895.jpg
#   inflating: image/n0679411000000897.jpg
#   inflating: image/n0679411000000898.jpg
#   inflating: image/n0679411000000899.jpg
#   inflating: image/n0679411000000900.jpg
#   inflating: image/n0679411000000901.jpg
#   inflating: image/n0679411000000902.jpg
#   inflating: image/n0679411000000904.jpg
#   inflating: image/n0679411000000905.jpg
#   inflating: image/n0679411000000909.jpg
#   inflating: image/n0679411000000912.jpg
#   inflating: image/n0679411000000913.jpg
#   inflating: image/n0679411000000916.jpg
#   inflating: image/n0679411000000918.jpg
#   inflating: image/n0679411000000919.jpg
#   inflating: image/n0679411000000923.jpg
# ...

# %%
! python /content/UNICORN-MAML/train_fsl.py
# Out:
# {'backbone_class': 'Res12',
#  'dataset': 'MiniImageNet',
#  'episodes_per_epoch': 100,
#  'eval_interval': 5,
#  'eval_query': 15,
#  'eval_shot': 1,
#  'eval_way': 5,
#  'fix_BN': False,
#  'gamma': 0.5,
#  'gd_lr': 0.001,
#  'gpu': '0',
#  'inner_iters': 5,
#  'log_interval': 50,
#  'lr': 0.001,
#  'lr_mul': 10,
#  'lr_scheduler': 'cosine',
#  'max_epoch': 200,
#  'model_class': 'MAML',
#  'mom': 0.9,
#  'noise_ratio': 0.1,
#  'noise_type': 'PCA',
#  'num_eval_episodes': 500,
#  'num_workers': 4,
#  'para_init': '/content/Res12-pre (1).pth',
#  'query': 15,
#  'save_dir': './checkpoints',
#  'save_path': './checkpoints/MiniImageNet-MAML-Res12-05w03s15q-Pre/100_0.5_lr0.001_InLR0.001InIter5_cosine_t0.5-Mul10',
#  'shot': 3,
#  'step_size': '100',
#  'temperature': 0.5,
#  'way': 5,
#  'weight_decay': 0.0005}
# using gpu: 0
# ...
# 100%|█████████████████| 12000/12000 [00:00<00:00, 656240.11it/s]
# ...
